# %%
# !pip install --upgrade multion -q

# %%
import multion

# %%
multion.login()
# Out:
# Already logged in.

# %%
response = multion.set_remote(True)
response
# Out:
# data: <Response [200]>
# data: True
# True

# %%
multion.get_remote()
# Out:
# True

# %%
response = multion.new_session({"input": "what is the weather today","url": "https://www.google.com"})
print(response['message'])
tabId = response['tabId']
tabId
# Out:
# running new session
# Request failed with status code: 500
# Response text: Internal Server Error
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 response = multion.new_session({"input": "what is the weather today","url": "https://www.google.com"})
#       2 print(response['message'])
#       3 tabId = response['tabId']
#
# File ~/Documents/MultiON/api/sdks/multion-py/multion.py:343, in new_session(data)
#     342 def new_session(data):
# --> 343     return _multion_instance.new_session(data)
#
# File ~/Documents/MultiON/api/sdks/multion-py/multion.py:217, in _Multion.new_session(self, data)
#     215 url = f"{self.api_url}/sessions"
#     216 print("running new session")
# --> 217 return self.post(url, data)
#
# File ~/Documents/MultiON/api/sdks/multion-py/multion.py:203, in _Multion.post(self, url, data, tabId)
#     201 print(f"Request failed with status code: {response.status_code}")
#     202 print(f"Response text: {response.text}")
# --> 203 raise Exception("Failed to get a valid response after 5 attempts")
#
# Exception: Failed to get a valid response after 5 attempts

# %%
response = multion.update_session(tabId, {"input": "what is the weather today","url": "https://www.google.com"})
response['message']
# Out:
# session updated
# 'The weather today is sunny with a temperature of 75°F. The precipitation is 0%, humidity is 66%, and the wind speed is 12 mph.\n\n'

# %%
multion.close_session(tabId)
# Out:
# {'data': 'Session terminated'}

# %%
multion.get_screenshot(response, height=800)
# Out:
# <PIL.Image.Image image mode=RGB size=823x800>

# %%
# Out:
# {'data': 'Session terminated'}
